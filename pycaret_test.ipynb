# %%
import pandas as pd

# %%
data = pd.read_pickle('single_5_year_surv.pkl')

# %%
sample = data.sample(10000)

# %%
from pycaret.clustering import *
s = setup(sample, normalize = True)
# Out:
# <style type="text/css">
# #T_f0b72_row2_col1, #T_f0b72_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f0b72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0b72_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f0b72_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0b72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0b72_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f0b72_row0_col1" class="data row0 col1" >1307</td>
#     </tr>
#     <tr>
#       <th id="T_f0b72_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0b72_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_f0b72_row1_col1" class="data row1 col1" >(10000, 17)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans = create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0      0.0878           892.3888            2.76            0           0
#
#    Completeness
# 0             0

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
plot_model(kmeans, plot = 'si')
